# %% [markdown]
# Cadenas de texto

# %%
cadena = """ este es un texto largo
- punto 1
- punto 2
- punto 3"""

cadena
# Out:
# La ejecución de celdas con 'Python 3.13.9' requiere el paquete ipykernel.
#
# Instale "ipykernel" en el entorno de Python.
#
# Comando: ""c:/Users/Alumnos Tarde/AppData/Local/Microsoft/WindowsApps/python3.13.exe" -m pip install ipykernel -U --user --force-reinstall"
